# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("cleaned_netflix_dataset.csv")

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                        unknowm
# 2                Julien Leclercq
# 3                        unknowm
# 4                        unknowm
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb          unknowm
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#       date_added  release_year rating   duration  \
# 8802  2019-11-20          2007      R    158 min
# 8803  2019-07-01          2018  TV-Y7  2 Seasons
# 8804  2019-11-01          2009      R     88 min
# ...

# %%
df.shape
# Out:
# (8807, 19)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'title_upper', 'title_length', 'year_added', 'month_added',
#        'content_age', 'duration_num', 'duration_type'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        8807 non-null   object
#  1   type           8807 non-null   object
#  2   title          8807 non-null   object
#  3   director       8807 non-null   object
#  4   cast           7982 non-null   object
#  5   country        7976 non-null   object
#  6   date_added     8797 non-null   object
#  7   release_year   8807 non-null   int64
#  8   rating         8803 non-null   object
#  9   duration       8804 non-null   object
#  10  listed_in      8807 non-null   object
#  11  description    8807 non-null   object
#  12  title_upper    8807 non-null   object
#  13  title_length   8807 non-null   int64
#  14  year_added     8797 non-null   float64
#  15  month_added    8797 non-null   float64
#  16  content_age    8807 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director           0
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# title_upper        0
# title_length       0
# year_added        10
# month_added       10
# content_age        0
# duration_num       3
# duration_type      3
# dtype: int64

# %%
df[df['director'].isnull()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, title_upper, title_length, year_added, month_added, content_age, duration_num, duration_type]
# Index: []

# %%
df['director'] = df['director'].fillna("Unknown")

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies = df[df['type'] == 'Movie']
movies.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country  date_added  \
# ...

# %%
tvshows = df[df['type'] == 'TV Show']
tvshows.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water          unknowm
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          unknowm
# 4      s5  TV Show           Kota Factory          unknowm
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#    date_added  release_year rating   duration  \
# 1  2021-09-24          2021  TV-MA  2 Seasons
# 2  2021-09-24          2021  TV-MA   1 Season
# 3  2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df[df['release_year'] > 2020]
# Out:
#      show_id     type                      title         director  \
# 1         s2  TV Show              Blood & Water          unknowm
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans          unknowm
# 4         s5  TV Show               Kota Factory          unknowm
# 5         s6  TV Show              Midnight Mass    Mike Flanagan
# ...      ...      ...                        ...              ...
# 1468   s1469    Movie  What Happened to Mr. Cha?     Kim Dong-kyu
# 1551   s1552  TV Show                      Hilda          unknowm
# 1696   s1697  TV Show               Polly Pocket          unknowm
# 2920   s2921  TV Show              Love Is Blind          unknowm
# 8437   s8438  TV Show     The Netflix Afterparty          unknowm
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df[df['country'].str.contains('India', na=False)]
# Out:
#      show_id     type                title                 director  \
# 4         s5  TV Show         Kota Factory                  unknowm
# 24       s25    Movie                Jeans               S. Shankar
# 29       s30    Movie             Paranoia           Robert Luketic
# 39       s40  TV Show         Chhota Bheem                  unknowm
# 50       s51  TV Show        Dharmakshetra                  unknowm
# ...      ...      ...                  ...                      ...
# 8773   s8774    Movie  Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show      Yeh Meri Family                  unknowm
# 8798   s8799    Movie             Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                Zenda           Avadhoot Gupte
# 8806   s8807    Movie               Zubaan              Mozez Singh
#
#                                                    cast  \
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...

# %%
df[df['title'].str.contains('love', case =False , na=False)]
# Out:
#      show_id     type                           title  \
# 25       s26  TV Show            Love on the Spectrum
# 158     s159    Movie         Love Don't Cost a Thing
# 159     s160    Movie                  Love in a Puff
# 206     s207    Movie       LSD: Love, Sex Aur Dhokha
# 227     s228    Movie                     Really Love
# ...      ...      ...                             ...
# 8567   s8568  TV Show  The Year of Happiness and Love
# 8575   s8576  TV Show                 This Is My Love
# 8649   s8650    Movie           Two Lovers and a Bear
# 8721   s8722  TV Show                   What Is Love?
# 8725   s8726    Movie            What's Up With Love?
#
#                        director  \
# 25                      unknowm
# 158                   Troy Byer
# 159              Pang Ho-cheung
# 206            Dibakar Banerjee
# 227       Angel Kristi Williams
# ...                         ...
# 8567                    unknowm
# 8575                    unknowm
# ...

# %%
df['title_upper'] = df['title'].str.upper()
df[['title', 'title_upper']].head()
# Out:
#                    title            title_upper
# 0   Dick Johnson Is Dead   DICK JOHNSON IS DEAD
# 1          Blood & Water          BLOOD & WATER
# 2              Ganglands              GANGLANDS
# 3  Jailbirds New Orleans  JAILBIRDS NEW ORLEANS
# 4           Kota Factory           KOTA FACTORY

# %%
df['title_length'] = df['title'].fillna('').str.len()

df[['title', 'title_length']].head()
# Out:
#                    title  title_length
# 0   Dick Johnson Is Dead            20
# 1          Blood & Water            13
# 2              Ganglands             9
# 3  Jailbirds New Orleans            21
# 4           Kota Factory            12

# %%
df.sort_values(by='release_year')
# Out:
#      show_id     type                               title  \
# 4250   s4251  TV Show   Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                      Prelude to War
# 8205   s8206    Movie                The Battle of Midway
# 8763   s8764    Movie     WWII: Report from the Aleutians
# 8739   s8740    Movie  Why We Fight: The Battle of Russia
# ...      ...      ...                                 ...
# 1310   s1311  TV Show                            The Crew
# 30       s31    Movie                     Ankahi Kahaniya
# 64       s65    Movie                          Nightbooks
# 1317   s1318  TV Show                        Nadiya Bakes
# 12       s13    Movie                        Je Suis Karl
#
#                                                director  \
# 4250                                            unknowm
# 7790                                        Frank Capra
# 8205                                          John Ford
# ...

# %%
df.sort_values(by='release_year')[['title','release_year']].head(20)
# Out:
#                                                  title  release_year
# 4250                 Pioneers: First Women Filmmakers*          1925
# 7790                                    Prelude to War          1942
# 8205                              The Battle of Midway          1942
# 8763                   WWII: Report from the Aleutians          1943
# 8739                Why We Fight: The Battle of Russia          1943
# 8660     Undercover: How to Operate Behind Enemy Lines          1943
# 8436                                 The Negro Soldier          1944
# 8419  The Memphis Belle: A Story of a\nFlying Fortress          1944
# 8640                                  Tunisian Victory          1944
# 7575                          Nazi Concentration Camps          1945
# 7219                           Know Your Enemy - Japan          1945
# 1331               Five Came Back: The Reference Films          1945
# 7930                                        San Pietro          1945
# ...

# %%
df.sort_values(by='release_year',ascending=False)[['title','release_year']].head(20)
# Out:
#                                                title  release_year
# 8                      The Great British Baking Show          2021
# 372                   Rurouni Kenshin: The Beginning          2021
# 74         The World's Most Amazing Vacation Rentals          2021
# 373                               The Last Mercenary          2021
# 375                                   Resort to Love          2021
# 20   Monsters Inside: The 24 Faces of Billy Milligan          2021
# 376         Transformers: War for Cybertron: Kingdom          2021
# 70                         Too Hot To Handle: Latino          2021
# 36                                    The Stronghold          2021
# 75                            You vs. Wild: Out Cold          2021
# 125                                          Q-Force          2021
# 80                       Firedrake the Silver Dragon          2021
# 81                                              Kate          2021
# ...

# %%
df.groupby('type')['show_id'].count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: show_id, dtype: int64

# %%
df.groupby('type')['show_id'].count().reset_index(name='total_count')
# Out:
#       type  total_count
# 0    Movie         6131
# 1  TV Show         2676

# %%
df.groupby('country')['show_id'].count().sort_values(ascending=False).head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: show_id, dtype: int64

# %%
df.groupby('type')['release_year'].mean()
# Out:
# type
# Movie      2013.121514
# TV Show    2016.605755
# Name: release_year, dtype: float64

# %%
df.groupby('type')['release_year'].mean().round(2)
# Out:
# type
# Movie      2013.12
# TV Show    2016.61
# Name: release_year, dtype: float64

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df['rating'].value_counts().head(10)
# Out:
# rating
# TV-MA    3207
# TV-14    2160
# TV-PG     863
# R         799
# PG-13     490
# TV-Y7     334
# TV-Y      307
# PG        287
# TV-G      220
# NR         80
# Name: count, dtype: int64

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
df['date_added'].dtype
# Out:
# dtype('O')

# %%
df['date_added'] = df['date_added'].str.strip()

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df['date_added'] = pd.to_datetime(
    df['date_added'],
    errors='coerce'
)

# %%
df['date_added'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df[df['date_added'].dt.year == 2021]
# Out:
#      show_id     type                                           title  \
# 0         s1    Movie                            Dick Johnson Is Dead
# 1         s2  TV Show                                   Blood & Water
# 2         s3  TV Show                                       Ganglands
# 3         s4  TV Show                           Jailbirds New Orleans
# 4         s5  TV Show                                    Kota Factory
# ...      ...      ...                                             ...
# 8272   s8273    Movie                                    The Departed
# 8320   s8321    Movie                 The Girl with the Dragon Tattoo
# 8434   s8435    Movie  The Naked Gun: From the Files of Police Squad!
# 8437   s8438  TV Show                          The Netflix Afterparty
# 8461   s8462    Movie                               The Polar Express
#
#              director                                               cast  \
# ...

# %%
df[df['date_added'].dt.year == 2021][['title', 'date_added']]
# Out:
#                                                title date_added
# 0                               Dick Johnson Is Dead 2021-09-25
# 1                                      Blood & Water 2021-09-24
# 2                                          Ganglands 2021-09-24
# 3                              Jailbirds New Orleans 2021-09-24
# 4                                       Kota Factory 2021-09-24
# ...                                              ...        ...
# 8272                                    The Departed 2021-01-01
# 8320                 The Girl with the Dragon Tattoo 2021-01-05
# 8434  The Naked Gun: From the Files of Police Squad! 2021-01-01
# 8437                          The Netflix Afterparty 2021-01-02
# 8461                               The Polar Express 2021-01-01
#
# [1498 rows x 2 columns]

# %%
pd.to_datetime(df['date_added'])
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 8807, dtype: datetime64[ns]

# %%
# Convert date column
df['date_added'] = pd.to_datetime(
    df['date_added'],
    errors='coerce'
)

# Create year column
df['year_added'] = df['date_added'].dt.year

# Create month column
df['month_added'] = df['date_added'].dt.month

# %%
# Convert date column
df['date_added'] = pd.to_datetime(
    df['date_added'],
    errors='coerce'
)

# Create year column
df['year_added'] = df['date_added'].dt.year

# Create month column
df['month_added'] = df['date_added'].dt.month

# %%
df['content_age'] = 2026 - df['release_year']

# %%
df[['title', 'release_year', 'content_age']].head()
# Out:
#                    title  release_year  content_age
# 0   Dick Johnson Is Dead          2020            6
# 1          Blood & Water          2021            5
# 2              Ganglands          2021            5
# 3  Jailbirds New Orleans          2021            5
# 4           Kota Factory          2021            5

# %%
df[['title', 'release_year', 'content_age']].head()
# Out:
#                    title  release_year  content_age
# 0   Dick Johnson Is Dead          2020            6
# 1          Blood & Water          2021            5
# 2              Ganglands          2021            5
# 3  Jailbirds New Orleans          2021            5
# 4           Kota Factory          2021            5

# %%
df[df['duration'].fillna('').str.contains('min')]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df[df['duration'].fillna('').str.contains('min')][['title', 'duration']]
# Out:
#                                  title duration
# 0                 Dick Johnson Is Dead   90 min
# 6     My Little Pony: A New Generation   91 min
# 7                              Sankofa  125 min
# 9                         The Starling  104 min
# 12                        Je Suis Karl  127 min
# ...                                ...      ...
# 8801                           Zinzana   96 min
# 8802                            Zodiac  158 min
# 8804                        Zombieland   88 min
# 8805                              Zoom   88 min
# 8806                            Zubaan  111 min
#
# [6128 rows x 2 columns]

# %%
df[['duration_num', 'duration_type']] = df['duration'].str.split(
    ' ',
    expand=True
)

# %%
df[['duration', 'duration_num', 'duration_type']].head()
# Out:
#     duration duration_num duration_type
# 0     90 min           90           min
# 1  2 Seasons            2       Seasons
# 2   1 Season            1        Season
# 3   1 Season            1        Season
# 4  2 Seasons            2       Seasons

# %%
df['duration_num'] = pd.to_numeric(
    df['duration_num'],
    errors='coerce'
)

# %%
df['duration_num'].dtype
# Out:
# dtype('float64')

# %%
movies = df[df['duration_type'] == 'min']

# %%
movies.sort_values(
    by='duration_num',
    ascending=False
)[['title', 'duration_num']].head(10)
# Out:
#                             title  duration_num
# 4253   Black Mirror: Bandersnatch         312.0
# 717   Headspace: Unwind Your Mind         273.0
# 2491       The School of Mischief         253.0
# 2487               No Longer kids         237.0
# 2484           Lock Your Girls In         233.0
# 2488              Raya and Sakina         230.0
# 166   Once Upon a Time in America         229.0
# 7932                       Sangam         228.0
# 1019                       Lagaan         224.0
# 4573                 Jodhaa Akbar         214.0

# %%
tvshows = df[df['duration_type'].str.contains('Season', na=False)]

# %%
tvshows.sort_values(
    by='duration_num',
    ascending=False
)[['title', 'duration_num']].head(10)
# Out:
#                        title  duration_num
# 548           Grey's Anatomy          17.0
# 4798                    NCIS          15.0
# 2423            Supernatural          15.0
# 1354               Heartland          13.0
# 4220  COMEDIANS of the world          13.0
# 7847            Red vs. Blue          13.0
# 4964       Trailer Park Boys          12.0
# 5412          Criminal Minds          12.0
# 6795                 Frasier          11.0
# 6456                  Cheers          11.0

# %%
df.loc[0:5, ['title', 'country']]
# Out:
#                    title        country
# 0   Dick Johnson Is Dead  United States
# 1          Blood & Water   South Africa
# 2              Ganglands            NaN
# 3  Jailbirds New Orleans            NaN
# 4           Kota Factory          India
# 5          Midnight Mass            NaN

# %%
df.iloc[0:5, 0:3]
# Out:
#   show_id     type                  title
# 0      s1    Movie   Dick Johnson Is Dead
# 1      s2  TV Show          Blood & Water
# 2      s3  TV Show              Ganglands
# 3      s4  TV Show  Jailbirds New Orleans
# 4      s5  TV Show           Kota Factory

# %%
df[
    (df['type'] == 'Movie') &
    (df['release_year'] > 2019)
]
# Out:
#      show_id   type                               title  \
# 0         s1  Movie                Dick Johnson Is Dead
# 6         s7  Movie    My Little Pony: A New Generation
# 9        s10  Movie                        The Starling
# 12       s13  Movie                        Je Suis Karl
# 13       s14  Movie    Confessions of an Invisible Girl
# ...      ...    ...                                 ...
# 3046   s3047  Movie       All the Freckles in the World
# 3060   s3061  Movie                       Ghost Stories
# 5972   s5973  Movie                    #cats_the_mewvie
# 7594   s7595  Movie  Norm of the North: Family Vacation
# 8099   s8100  Movie                         Straight Up
#
#                                                director  \
# 0                                       Kirsten Johnson
# 6                         Robert Cullen, José Luis Ucha
# 9                                        Theodore Melfi
# 12                                  Christian Schwochow
# ...

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['country'].nunique()
# Out:
# 748

# %%
df['director'].value_counts().head(10)
# Out:
# director
# unknowm                   2634
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Martin Scorsese             12
# Youssef Chahine             12
# Jay Chapman                 12
# Name: count, dtype: int64

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
df['release_year'].value_counts().sort_index()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: count, Length: 74, dtype: int64

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
top_countries = (
    df['country']
    .fillna('Unknown')
    .value_counts()
    .head(10)
)

top_countries.plot(kind='bar')

plt.xlabel("Country")
plt.ylabel("Number of Content")
plt.title("Top 10 Countries Producing Netflix Content")

plt.xticks(rotation=45)

plt.show()

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df[['release_year', 'content_age']].corr()
# Out:
#               release_year  content_age
# release_year           1.0         -1.0
# content_age           -1.0          1.0

# %%
pd.pivot_table(
    df,
    index='release_year',
    columns='type',
    values='show_id',
    aggfunc='count'
)
# Out:
# type          Movie  TV Show
# release_year
# 1925            NaN      1.0
# 1942            2.0      NaN
# 1943            3.0      NaN
# 1944            3.0      NaN
# 1945            3.0      1.0
# ...             ...      ...
# 2017          767.0    265.0
# 2018          767.0    380.0
# 2019          633.0    397.0
# 2020          517.0    436.0
# 2021          277.0    315.0
#
# [74 rows x 2 columns]

# %%
df.to_csv(
    'cleaned_netflix_dataset.csv',
    index=False
)

# %%
total_movies = df[df['type'] == 'Movie'].shape[0]

total_tvshows = df[df['type'] == 'TV Show'].shape[0]

top_country = df['country'].value_counts().idxmax()

most_common_rating = df['rating'].value_counts().idxmax()

latest_year = df['release_year'].max()

# %%
print("Total Movies:", total_movies)
print("Total TV Shows:", total_tvshows)
print("Top Country:", top_country)
print("Most Common Rating:", most_common_rating)
print("Latest Release Year:", latest_year)
# Out:
# Total Movies: 6131
# Total TV Shows: 2676
# Top Country: United States
# Most Common Rating: TV-MA
# Latest Release Year: 2021

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# Step 2: PostgreSQL connection details
username = "postgres"
password = "Mohanraj2006"      # Your PostgreSQL password
host = "localhost"
port = "5432"
database = "netflix_content_analysis"  # Create this database in pgAdmin first

# Step 3: Create connection
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# Step 4: Upload DataFrame to PostgreSQL
table_name = "netflix"

df.to_sql(
    table_name,
    engine,
    if_exists="replace",   # Replaces existing table
    index=False
)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'netflix' in database 'netflix_content_analysis'.
